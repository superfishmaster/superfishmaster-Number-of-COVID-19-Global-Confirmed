# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
Global= (r"C:\Everything\Data\2020Spring\Datavis\COVID-19-master\csse_covid_19_data\csse_covid_19_time_series\time_series_covid19_confirmed_global.csv")        
df = pd.read_csv(Global)
df
# Out:
#                        Province/State Country/Region        Lat       Long  \
# 0                                 NaN    Afghanistan  33.000000  65.000000
# 1                                 NaN        Albania  41.153300  20.168300
# 2                                 NaN        Algeria  28.033900   1.659600
# 3                                 NaN        Andorra  42.506300   1.521800
# 4                                 NaN         Angola -11.202700  17.873900
# ..                                ...            ...        ...        ...
# 253                               NaN       Botswana -22.328500  24.684900
# 254                               NaN        Burundi  -3.373100  29.918900
# 255                               NaN   Sierra Leone   8.460555 -11.779889
# 256  Bonaire, Sint Eustatius and Saba    Netherlands  12.178400 -68.238500
# 257                               NaN         Malawi -13.254308  34.301525
#
# ...

# %%
y=df.iloc[0:257,4:76].sum()
y
# Out:
# 1/22/20        555
# 1/23/20        654
# 1/24/20        941
# 1/25/20       1434
# 1/26/20       2118
#             ...
# 3/29/20     720117
# 3/30/20     782365
# 3/31/20     857487
# 4/1/20      932605
# 4/2/20     1013154
# Length: 72, dtype: int64

# %%
x=df.columns[4:76]
x
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20',
#        '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20',
#        '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20',
#        '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20',
#        '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20',
#        '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20',
#        '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20',
#        '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20',
#        '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20', '3/24/20',
#        '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20', '3/30/20',
#        '3/31/20', '4/1/20', '4/2/20'],
#       dtype='object')

# %%
plt.figure()
plt.plot(x,y,'y.-')
plt.title('Number of COVID-19 Global Confirmed')
plt.xticks(['1/22/20', '2/29/20', '3/31/20','4/2/20'],['','February', 'March',''])
plt.savefig("easyplot.jpg")
